# %% [markdown]
# <img src="logo.png" width="200"/>

# %% [markdown]
# # Groupby
#
# O método groupby permite agrupar linhas de dados em conjunto e chamar funções agregadas

# %%
import pandas as pd
# Cria um DataFrame
data = {'Classe':['Júnior','Júnior','Pleno','Pleno','Sênior','Sênior'],
       'Nome':['Jorge','Carlos','Roberta','Patrícia','Bruno','Vera'],
       'Venda':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %% [markdown]
# ** Agora, você pode usar o método .group by () para agrupar as linhas em conjunto com base em um nome de coluna. Por exemplo, vamos agrupar com base na empresa. Isso criará um objeto DataFrameGroupBy:**

# %%
df.groupby('Empresa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.groupby('Empresa')
#
# File c:\Users\ferna\miniconda3\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\ferna\miniconda3\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File c:\Users\ferna\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\ferna\miniconda3\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'Empresa'

# %% [markdown]
# Você pode salvar este objeto como uma nova variável:

# %%
por_companhia = df.groupby("Empresa")

# %% [markdown]
# E, em seguida, chamar métodos agregados do objeto:

# %%
por_companhia.mean()
# Out:
#          Venda
# Empresa
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Empresa').mean()
# Out:
#          Venda
# Empresa
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %% [markdown]
# Mais exemplos de métodos agregados:

# %%
por_companhia.std()
# Out:
#               Venda
# Empresa
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
por_companhia.min()
# Out:
#             Nome  Venda
# Empresa
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
por_companhia.max()
# Out:
#             Nome  Venda
# Empresa
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
por_companhia.count()
# Out:
#          Nome  Venda
# Empresa
# FB          2      2
# GOOG        2      2
# MSFT        2      2

# %%
por_companhia.describe()
# Out:
#         Venda
#         count   mean         std    min     25%    50%     75%    max
# Empresa
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
por_companhia.describe().transpose()
# Out:
# Empresa              FB        GOOG        MSFT
# Venda count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
por_companhia.describe().transpose()['GOOG']
# Out:
# Venda  count      2.000000
#        mean     160.000000
#        std       56.568542
#        min      120.000000
#        25%      140.000000
#        50%      160.000000
#        75%      180.000000
#        max      200.000000
# Name: GOOG, dtype: float64
